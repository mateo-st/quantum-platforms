# %%
import numpy as np
import matplotlib.pyplot as plt
from pulser import Pulse, Sequence, Register
from pulser_simulation import QutipEmulator
from pulser.devices import DigitalAnalogDevice
from pulser.waveforms import InterpolatedWaveform
from scipy.optimize import minimize
from scipy.spatial.distance import pdist, squareform

import generate

# %%
Q, x = generate.qubo_matrix(20,1)
Q
# Out:
# array([[ 0.65323528,  0.99635553,  0.58190154,  0.329838  ,  0.13392378,
#          0.03007693,  0.40024096,  0.51939987,  0.03335896,  0.56791055,
#          0.27766099,  0.76395816,  0.11654066,  0.66828017,  0.49933894,
#          0.30580931,  0.41432988,  0.90505738,  0.59736436,  0.23466049],
#        [ 0.01344209,  0.67021064,  0.11269284,  0.5830051 ,  0.69695371,
#          0.58349416,  0.90825824,  0.21783351,  0.41359502,  0.59676682,
#          0.53070408,  0.09491557,  0.05073174,  0.94280763,  0.30754501,
#          0.33531774,  0.74364707,  0.88347117,  0.93620854,  0.62118856],
#        [ 0.07084113,  0.02954427,  0.98195198,  0.05389826,  0.01407361,
#          0.69344378,  0.19257963,  0.62924358,  0.94858805,  0.47392412,
#          0.30514208,  0.12000267,  0.71785936,  0.56633881,  0.34063319,
#          0.59383066,  0.10727665,  0.29708226,  0.83097695,  0.58232351],
#        [ 0.84840292,  0.53124526,  0.19338235,  0.30360964,  0.24770085,
#          0.35640158,  0.38927336,  0.60389578,  0.08099381,  0.5338774 ,
#          0.80920394,  0.11846447,  0.83469196,  0.78885826,  0.47744897,
#          0.99224945,  0.83691901,  0.61202363,  0.21290696,  0.15516437],
#        [ 0.27185107,  0.34214149,  0.01262249,  0.92767966,  0.25303136,
#          0.34762729,  0.29154208,  0.99596504,  0.14812843,  0.6018162 ,
#          0.98249076,  0.37416269,  0.38253448,  0.31146676,  0.68983022,
#          0.83429995,  0.78552249,  0.64993775,  0.83537081,  0.09689906],
#        [ 0.44779303,  0.15894478,  0.8195317 ,  0.59121881,  0.67915171,
#          0.37173573,  0.54101996,  0.78416641,  0.88497824,  0.57487239,
#          0.3270441 ,  0.47218874,  0.83230718,  0.33440652,  0.55605247,
#          0.55483603,  0.10580814,  0.34379881,  0.0803759 ,  0.28461459],
#        [ 0.81095118,  0.08133163,  0.33418518,  0.83667433,  0.95716829,
#          0.35681587,  0.02491346,  0.49373629,  0.56698379,  0.65906379,
#          0.36972733,  0.12133228,  0.39763179,  0.67565919,  0.487116  ,
#          0.83789612,  0.58858707,  0.54812211,  0.99461325,  0.96250104],
#        [ 0.04002435,  0.13002481,  0.32605012,  0.10974742,  0.56459884,
#          0.19036131,  0.77806486,  0.47939207,  0.24712357,  0.49019146,
#          0.96188771,  0.26939527,  0.61206311,  0.85713159,  0.68491331,
#          0.61672135,  0.30733311,  0.60091058,  0.77129852,  0.8649533 ],
#        [ 0.61362945,  0.13846607,  0.52946138,  0.46792029,  0.91238519,
#          0.20666358,  0.861623  ,  0.2685294 ,  0.35696738,  0.2017524 ,
#          0.0555766 ,  0.26614177,  0.92148298,  0.95642197,  0.3869502 ,
#          0.86255334,  0.12745234,  0.15341012,  0.8054232 ,  0.16509285],
#          0.88846443,  0.11024747,  0.87626168,  0.80873252,  0.82607652,
#          0.20804938,  0.41758272,  0.06134425,  0.75075493,  0.79309515,
#          0.45103862,  0.56207819,  0.56576595,  0.82958408,  0.32971099]])

# %%
def evaluate_mapping(new_coords, *args):
    """Cost function to minimize. Ideally, the pairwise
    distances are conserved"""
    Q, shape = args
    new_coords = np.reshape(new_coords, shape)
    new_Q = squareform(
        DigitalAnalogDevice.interaction_coeff / pdist(new_coords) ** 6
    )
    return np.linalg.norm(new_Q - Q)

# %%
shape = (len(Q), 2)
costs = []
np.random.seed(0)
x0 = np.random.random(shape).flatten()
res = minimize(
    evaluate_mapping,
    x0,
    args=(Q, shape),
    method="COBYLA",
    tol=1e-9,
    options={"maxiter": 50000, "maxfev": None},
)
coords = np.reshape(res.x, (len(Q), 2))
# Out:
# /Users/targuelles/Library/Caches/pypoetry/virtualenvs/basic-qubo-2hUiBxcz-py3.10/lib/python3.10/site-packages/scipy/optimize/_minimize.py:719: OptimizeWarning: Unknown solver options: maxfev
#   res = _minimize_cobyla(fun, x0, args, constraints, callback=callback,

# %%
qubits = dict(enumerate(coords))
reg = Register(qubits)
reg.draw(
    blockade_radius=DigitalAnalogDevice.rydberg_blockade_radius(1),
    draw_graph=False,
    draw_half_radius=True,
)

# %%
def get_cost_colouring(bitstring, Q):
    z = np.array(list(bitstring), dtype=int)
    cost = z.T @ Q @ z
    return cost


def get_cost(counter, Q):
    cost = sum(counter[key] * get_cost_colouring(key, Q) for key in counter)
    return cost / sum(counter.values())  # Divide by total samples

# %%
def plot_distribution(C):
    C = dict(sorted(C.items(), key=lambda item: item[1], reverse=True))
    indexes = []  # QUBO solutions
    color_dict = {key: "r" if key in indexes else "g" for key in C}
    plt.figure(figsize=(12, 6))
    plt.xlabel("bitstrings")
    plt.ylabel("counts")
    plt.bar(C.keys(), C.values(), width=0.5, color=color_dict.values())
    plt.xticks(rotation="vertical")
    plt.show()

# %%
# We choose a median value between the min and the max
Omega = np.median(Q[Q > 0].flatten())
delta_0 = -1.0002  # just has to be negative
delta_f = -delta_0  # just has to be positive
T = 4000  # time in ns, we choose a time long enough to ensure the propagation of information in the system

# %%
adiabatic_pulse = Pulse(
    InterpolatedWaveform(T, [1e-9, Omega, 1e-9]),
    InterpolatedWaveform(T, [delta_0, 0, delta_f]),
    0,
)
seq = Sequence(reg, DigitalAnalogDevice)
seq.declare_channel("ising", "rydberg_global")
seq.add(adiabatic_pulse, "ising")
seq.draw()

# %%
simul = QutipEmulator.from_sequence(seq, sampling_rate=0.1)
results = simul.run()
final = results.get_final_state()
count_dict = results.sample_final_state()
plot_distribution(count_dict)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[27], line 2
#       1 simul = QutipEmulator.from_sequence(seq, sampling_rate=0.1)
# ----> 2 results = simul.run()
#       3 final = results.get_final_state()
#       4 count_dict = results.sample_final_state()
#
# File ~/Library/Caches/pypoetry/virtualenvs/basic-qubo-2hUiBxcz-py3.10/lib/python3.10/site-packages/pulser_simulation/simulation.py:594, in QutipEmulator.run(self, progress_bar, **options)
#     589 if set(self.config.noise).issubset(
#     590     {"dephasing", "relaxation", "SPAM", "depolarizing", "eff_noise"}
#     591 ):
#     592     # If there is "SPAM", the preparation errors must be zero
#     593     if "SPAM" not in self.config.noise or self.config.eta == 0:
# --> 594         return _run_solver()
#     596     else:
#     597         # Stores the different initial configurations and frequency
#     598         initial_configs = Counter(
#     599             "".join(
#     600                 (
#    (...)
#     609             for _ in range(self.config.runs)
#     610         ).most_common()
#
# File ~/Library/Caches/pypoetry/virtualenvs/basic-qubo-2hUiBxcz-py3.10/lib/python3.10/site-packages/pulser_simulation/simulation.py:563, in QutipEmulator.run.<locals>._run_solver()
#     554     result = qutip.mesolve(
#     555         self._hamiltonian._hamiltonian,
#     556         self.initial_state,
#    (...)
#     560         options=solv_ops,
#     561     )
#     562 else:
# --> 563     result = qutip.sesolve(
#     564         self._hamiltonian._hamiltonian,
#     565         self.initial_state,
#     566         self._eval_times_array,
#     567         progress_bar=p_bar,
#     568         options=solv_ops,
#     569     )
#     570 results = [
#     571     QutipResult(
#     572         tuple(self._hamiltonian._qdict),
#    (...)
#     577     for state in result.states
#     578 ]
#     579 return CoherentResults(
#     580     results,
#     581     self._hamiltonian._size,
#    (...)
#     585     meas_errors,
#     586 )
#
# File ~/Library/Caches/pypoetry/virtualenvs/basic-qubo-2hUiBxcz-py3.10/lib/python3.10/site-packages/qutip/sesolve.py:136, in sesolve(H, psi0, tlist, e_ops, args, options, progress_bar, _safe_mode)
#     133     v = psi0.full().ravel('F')
#     134     func(0., v, *ode_args) + v
# --> 136 res = _generic_ode_solve(func, ode_args, psi0, tlist, e_ops, options,
#     137                          progress_bar, dims=psi0.dims)
#     138 if e_ops_dict:
#     139     res.expect = {e: res.expect[n]
#     140                   for n, e in enumerate(e_ops_dict.keys())}
#
# File ~/Library/Caches/pypoetry/virtualenvs/basic-qubo-2hUiBxcz-py3.10/lib/python3.10/site-packages/qutip/sesolve.py:381, in _generic_ode_solve(func, ode_args, psi0, tlist, e_ops, opt, progress_bar, dims)
#     377             output.expect[m][t_idx] = cy_expect_psi(e_ops_data[m], cdata,
#     378                                                     e_ops[m].isherm)
#     380     if t_idx < n_tsteps - 1:
# --> 381         r.integrate(r.t + dt[t_idx])
#     383 progress_bar.finished()
#     385 if opt.store_final_state:
#
# File ~/Library/Caches/pypoetry/virtualenvs/basic-qubo-2hUiBxcz-py3.10/lib/python3.10/site-packages/scipy/integrate/_ode.py:431, in ode.integrate(self, t, step, relax)
#     428     mth = self._integrator.run
#     430 try:
# --> 431     self._y, self.t = mth(self.f, self.jac or (lambda: None),
#     432                           self._y, self.t, t,
#     433                           self.f_params, self.jac_params)
#     434 except SystemError as e:
#     435     # f2py issue with tuple returns, see ticket 1187.
#     436     raise ValueError(
#     437         'Function to integrate must not return a tuple.'
#     438     ) from e
#
# File ~/Library/Caches/pypoetry/virtualenvs/basic-qubo-2hUiBxcz-py3.10/lib/python3.10/site-packages/scipy/integrate/_ode.py:1008, in vode.run(self, f, jac, y0, t0, t1, f_params, jac_params)
#    1004     jac = _vode_banded_jac_wrapper(jac, self.ml, jac_params)
#    1006 args = ((f, jac, y0, t0, t1) + tuple(self.call_args) +
#    1007         (f_params, jac_params))
# -> 1008 y1, t, istate = self.runner(*args)
#    1009 self.istate = istate
#    1010 if istate < 0:
#
# KeyboardInterrupt:

# %%
count_dict.most_common()[:3:1]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 count_dict.most_common()[:3:1]
#
# NameError: name 'count_dict' is not defined
